# %%
import os
import cv2
import numpy as np
import pandas as pd
from tqdm import tqdm
import pydicom
import xgboost as xgb
from glob import glob
from sklearn import cross_validation
from keras.models import Model
from keras.applications.resnet50 import ResNet50, preprocess_input
# Out:
# /home/ianchan/Develop/Applications/anaconda3/lib/python3.6/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)
# /home/ianchan/Develop/Applications/anaconda3/lib/python3.6/site-packages/h5py/__init__.py:36: FutureWarning: Conversion of the second argument of issubdtype from `float` to `np.floating` is deprecated. In future, it will be treated as `np.float64 == np.dtype(float).type`.
#   from ._conv import register_converters as _register_converters
# Using TensorFlow backend.

# %%
seed=42

# %%
BASE_PATH = "/opt/data/liver_cancer"
TRAIN_PATH = os.path.join(BASE_PATH, "train_dataset")
TEST_PATH = os.path.join(BASE_PATH, "test_dataset")
TRAIN_LABEL_PATH = os.path.join(BASE_PATH, "train_label.csv")
SUBMIT_EXAMPLE_PATH = os.path.join(BASE_PATH, "submit_example.csv")
SUBMIT_PATH = os.path.join(BASE_PATH, "results", "submit.csv")

FEATURE_SAVE_PATH = os.path.join(BASE_PATH, "results", "resnet50_feature")

img_width, img_height, img_channel = 224, 224, 3

# %%
def read_ct_3d(ct_folder_path):
    slice_imgs = []
    for slice_name in sorted(os.listdir(ct_folder_path)):
            slice_folder_path = os.path.join(ct_folder_path, slice_name)
            slice_dicom = pydicom.read_file(slice_folder_path)
            slice_img = slice_dicom.pixel_array
            slice_img = cv2.resize(slice_img, (img_width, img_height))
            slice_imgs.append(slice_img)
            
    return np.stack(slice_imgs).astype(np.float32)

# %%
def get_data_batch(ct_3d_img):
    # combine 3 slices to make RGB images
    batch = []
    for i in range(0, ct_3d_img.shape[0]-3, 3):
        rgb_img = []
        for j in range(3):
            rgb_img.append(ct_3d_img[i+j])
            
        rgb_img = np.array(rgb_img)
        # channel first to channel last
        rgb_img = np.transpose(rgb_img, (1, 2, 0))
        batch.append(rgb_img)
        
    return np.array(batch)

# %%
def calc_features(folder_path):
    model = ResNet50(include_top=None, weights='imagenet')
    for ct_folder_name in tqdm(os.listdir(folder_path)):
        ct_folder_path = os.path.join(folder_path, ct_folder_name)
        
        ct_3d_img = read_ct_3d(ct_folder_path)
        batch = get_data_batch(ct_3d_img)
        batch = preprocess_input(batch)
        
        preds = model.predict(batch)
        # average pred for every patient
        preds = np.mean(preds, axis=0)
        preds= preds.reshape(-1)
        np.save(os.path.join(FEATURE_SAVE_PATH, ct_folder_name), preds)

# %%
calc_features(TRAIN_PATH)
# Out:
# 100%|██████████| 3600/3600 [18:24<00:00,  3.26it/s]

# %%
calc_features(TEST_PATH)
# Out:
# 100%|██████████| 3974/3974 [22:21<00:00,  2.96it/s]

# %%
def train_xgboost():
    df = pd.read_csv(TRAIN_LABEL_PATH)
    
    x = np.array([np.load(FEATURE_SAVE_PATH+"/%s.npy"%(name)) for name in df["id"].tolist()])
    y = df["ret"].as_matrix()
    print (x.shape, y.shape)
    
    train_X, val_X, train_y, val_y = cross_validation.train_test_split(x, y, random_state=seed, stratify=y, test_size=0.2)
    
    clf = xgb.XGBRegressor(max_depth=10,
                          n_estimators=1500,
                          min_child_weight=9,
                          learning_rate=0.05,
                          nthread=8,
                          subsample=0.80,
                          colsample_bylevel=0.80,
                          seed=seed)
    
    clf.fit(train_X, train_y, eval_set=[(val_X, val_y)], verbose=True, eval_metric="logloss", early_stopping_rounds=50)
    
    return clf

# %%
def test_and_make_submission():
    df = pd.read_csv(SUBMIT_EXAMPLE_PATH)
    
    clf = train_xgboost()
    x = np.array([np.load(FEATURE_SAVE_PATH+"/%s.npy"%(name)) for name in df["id"].tolist()])
    preds = clf.predict(x)
    
    # make submission
    df["ret"] = [1 if pred > 0.5 else 0 for pred in preds]
    df.to_csv(SUBMIT_PATH, index=False)
    print(df.head())

# %%
test_and_make_submission()
# Out:
#                                      id  ret
# 0  0013EDC2-8D7A-4A41-AEB5-D3BB592306D2    1
# 1  0030CBD1-2472-42C4-8CE4-E01A4E8E2F09    1
# 2  0036DF08-EEEC-467C-8CF1-5A54E0B13CE8    1
# 3  003D2553-266F-47E3-A420-F5B8F95217A7    0
# 4  0072E2C1-C395-409B-8078-365DD5C0513E    0
# (3600, 2048) (3600,)
# [0]	validation_0-logloss:0.663743
# Will train until validation_0-logloss hasn't improved in 50 rounds.
# [1]	validation_0-logloss:0.637379
# [2]	validation_0-logloss:0.612236
# [3]	validation_0-logloss:0.58747
# [4]	validation_0-logloss:0.565178
# [5]	validation_0-logloss:0.545206
# [6]	validation_0-logloss:0.527159
# [7]	validation_0-logloss:0.508771
# [8]	validation_0-logloss:0.493235
# [9]	validation_0-logloss:0.479213
# [10]	validation_0-logloss:0.463816
# [11]	validation_0-logloss:0.45074
# [12]	validation_0-logloss:0.438447
# [13]	validation_0-logloss:0.425956
# [14]	validation_0-logloss:0.413383
# [15]	validation_0-logloss:0.403099
# [16]	validation_0-logloss:0.393063
# [17]	validation_0-logloss:0.382723
# [18]	validation_0-logloss:0.373733
# [19]	validation_0-logloss:0.36567
# [20]	validation_0-logloss:0.356844
# [21]	validation_0-logloss:0.349029
# [22]	validation_0-logloss:0.340739
# [23]	validation_0-logloss:0.332924
# [24]	validation_0-logloss:0.326636
# [25]	validation_0-logloss:0.320029
# [26]	validation_0-logloss:0.312851
# [27]	validation_0-logloss:0.305781
# [28]	validation_0-logloss:0.299885
# [29]	validation_0-logloss:0.294151
# [30]	validation_0-logloss:0.28763
# [31]	validation_0-logloss:0.282649
# [32]	validation_0-logloss:0.277897
# [33]	validation_0-logloss:0.27312
# [34]	validation_0-logloss:0.267818
# [35]	validation_0-logloss:0.262531
# [36]	validation_0-logloss:0.258052
# [37]	validation_0-logloss:0.253908
# [38]	validation_0-logloss:0.249455
# [39]	validation_0-logloss:0.244926
# [40]	validation_0-logloss:0.241596
# [41]	validation_0-logloss:0.238173
# [42]	validation_0-logloss:0.234192
# [43]	validation_0-logloss:0.230844
# [44]	validation_0-logloss:0.227383
# [45]	validation_0-logloss:0.224079
# [46]	validation_0-logloss:0.221071
# [47]	validation_0-logloss:0.218284
# [48]	validation_0-logloss:0.215343
# [49]	validation_0-logloss:0.212546
# [50]	validation_0-logloss:0.209727
# [51]	validation_0-logloss:0.20729
# [52]	validation_0-logloss:0.204786
# [53]	validation_0-logloss:0.202419
# [54]	validation_0-logloss:0.200116
# [55]	validation_0-logloss:0.1972
# [56]	validation_0-logloss:0.194761
# [57]	validation_0-logloss:0.192667
# [58]	validation_0-logloss:0.190598
# [59]	validation_0-logloss:0.188664
# [60]	validation_0-logloss:0.186967
# [61]	validation_0-logloss:0.184851
# [62]	validation_0-logloss:0.183151
# [63]	validation_0-logloss:0.181896
# [64]	validation_0-logloss:0.18072
# [65]	validation_0-logloss:0.178998
# [66]	validation_0-logloss:0.177892
# [67]	validation_0-logloss:0.176306
# [68]	validation_0-logloss:0.175018
# [69]	validation_0-logloss:0.17363
# [70]	validation_0-logloss:0.172171
# [71]	validation_0-logloss:0.170945
# [72]	validation_0-logloss:0.169965
# [73]	validation_0-logloss:0.168786
# [74]	validation_0-logloss:0.167791
# [75]	validation_0-logloss:0.166589
# [76]	validation_0-logloss:0.165551
# [77]	validation_0-logloss:0.164343
# [78]	validation_0-logloss:0.163399
# [79]	validation_0-logloss:0.162376
# [80]	validation_0-logloss:0.161377
# [81]	validation_0-logloss:0.160488
# [82]	validation_0-logloss:0.15962
# [83]	validation_0-logloss:0.158893
# [84]	validation_0-logloss:0.158022
# [85]	validation_0-logloss:0.157428
# [86]	validation_0-logloss:0.156622
# [87]	validation_0-logloss:0.155911
# [88]	validation_0-logloss:0.155513
# [89]	validation_0-logloss:0.154958
# [90]	validation_0-logloss:0.15431
# [91]	validation_0-logloss:0.153468
# [92]	validation_0-logloss:0.153078
# [93]	validation_0-logloss:0.152773
# [94]	validation_0-logloss:0.152284
# [95]	validation_0-logloss:0.151654
# [96]	validation_0-logloss:0.151168
# [97]	validation_0-logloss:0.150583
# [98]	validation_0-logloss:0.150195
# [99]	validation_0-logloss:0.14973
# [100]	validation_0-logloss:0.149058
# [101]	validation_0-logloss:0.148584
# [102]	validation_0-logloss:0.148264
# [103]	validation_0-logloss:0.147843
# [104]	validation_0-logloss:0.147432
# [105]	validation_0-logloss:0.147106
# [106]	validation_0-logloss:0.146906
# [107]	validation_0-logloss:0.146642
# [108]	validation_0-logloss:0.14652
# [109]	validation_0-logloss:0.146287
# [110]	validation_0-logloss:0.145848
# [111]	validation_0-logloss:0.145564
# [112]	validation_0-logloss:0.145344
# [113]	validation_0-logloss:0.145137
# [114]	validation_0-logloss:0.144862
# [115]	validation_0-logloss:0.144694
# [116]	validation_0-logloss:0.144507
# [117]	validation_0-logloss:0.144006
# [118]	validation_0-logloss:0.143678
# [119]	validation_0-logloss:0.143463
# [120]	validation_0-logloss:0.143304
# [121]	validation_0-logloss:0.143096
# [122]	validation_0-logloss:0.142809
# [123]	validation_0-logloss:0.142472
# [124]	validation_0-logloss:0.142192
# [125]	validation_0-logloss:0.142011
# [126]	validation_0-logloss:0.141871
# [127]	validation_0-logloss:0.141511
# [128]	validation_0-logloss:0.141226
# [129]	validation_0-logloss:0.14097
# [130]	validation_0-logloss:0.140843
# [131]	validation_0-logloss:0.140556
# [132]	validation_0-logloss:0.140392
# [133]	validation_0-logloss:0.140251
# [134]	validation_0-logloss:0.140122
# [135]	validation_0-logloss:0.139863
# [136]	validation_0-logloss:0.139689
# [137]	validation_0-logloss:0.139529
# [138]	validation_0-logloss:0.139402
# [139]	validation_0-logloss:0.139282
# [140]	validation_0-logloss:0.139054
# [141]	validation_0-logloss:0.138995
# [142]	validation_0-logloss:0.138873
# [143]	validation_0-logloss:0.138728
# [144]	validation_0-logloss:0.138537
# [145]	validation_0-logloss:0.138492
# [146]	validation_0-logloss:0.138389
# [147]	validation_0-logloss:0.138239
# [148]	validation_0-logloss:0.13809
# [149]	validation_0-logloss:0.13796
# [150]	validation_0-logloss:0.13788
# [151]	validation_0-logloss:0.137762
# [152]	validation_0-logloss:0.137665
# [153]	validation_0-logloss:0.137572
# [154]	validation_0-logloss:0.137501
# [155]	validation_0-logloss:0.137312
# [156]	validation_0-logloss:0.137152
# [157]	validation_0-logloss:0.137096
# [158]	validation_0-logloss:0.137022
# [159]	validation_0-logloss:0.136924
# [160]	validation_0-logloss:0.136853
# [161]	validation_0-logloss:0.13669
# [162]	validation_0-logloss:0.136576
# [163]	validation_0-logloss:0.136509
# [164]	validation_0-logloss:0.13642
# [165]	validation_0-logloss:0.136382
# [166]	validation_0-logloss:0.13629
# [167]	validation_0-logloss:0.136156
# [168]	validation_0-logloss:0.136039
# [169]	validation_0-logloss:0.136016
# [170]	validation_0-logloss:0.135877
# [171]	validation_0-logloss:0.135769
# [172]	validation_0-logloss:0.135674
# [173]	validation_0-logloss:0.135578
# [174]	validation_0-logloss:0.135481
# [175]	validation_0-logloss:0.135406
# [176]	validation_0-logloss:0.13535
# [177]	validation_0-logloss:0.135289
# [178]	validation_0-logloss:0.135176
# [179]	validation_0-logloss:0.135135
# [180]	validation_0-logloss:0.135067
# [181]	validation_0-logloss:0.13504
# [182]	validation_0-logloss:0.13499
# [183]	validation_0-logloss:0.134925
# [184]	validation_0-logloss:0.134835
# [185]	validation_0-logloss:0.134762
# [186]	validation_0-logloss:0.134729
# [187]	validation_0-logloss:0.134691
# [188]	validation_0-logloss:0.134687
# [189]	validation_0-logloss:0.134638
# [190]	validation_0-logloss:0.134569
# [191]	validation_0-logloss:0.134488
# [192]	validation_0-logloss:0.134452
# [193]	validation_0-logloss:0.134418
# [194]	validation_0-logloss:0.134395
# [195]	validation_0-logloss:0.13441
# [196]	validation_0-logloss:0.134371
# [197]	validation_0-logloss:0.134318
# [198]	validation_0-logloss:0.134234
# [199]	validation_0-logloss:0.134202
# [200]	validation_0-logloss:0.134155
# [201]	validation_0-logloss:0.134118
# [202]	validation_0-logloss:0.134087
# [203]	validation_0-logloss:0.134068
# [204]	validation_0-logloss:0.134033
# [205]	validation_0-logloss:0.133964
# [206]	validation_0-logloss:0.133919
# [207]	validation_0-logloss:0.133862
# [208]	validation_0-logloss:0.133814
# [209]	validation_0-logloss:0.133772
# [210]	validation_0-logloss:0.13373
# [211]	validation_0-logloss:0.13367
# [212]	validation_0-logloss:0.133622
# [213]	validation_0-logloss:0.133591
# [214]	validation_0-logloss:0.133546
# [215]	validation_0-logloss:0.133522
# [216]	validation_0-logloss:0.13348
# [217]	validation_0-logloss:0.133432
# [218]	validation_0-logloss:0.133393
# [219]	validation_0-logloss:0.133337
# [220]	validation_0-logloss:0.133291
# [221]	validation_0-logloss:0.133247
# [222]	validation_0-logloss:0.133214
# [223]	validation_0-logloss:0.133176
# [224]	validation_0-logloss:0.133121
# [225]	validation_0-logloss:0.133069
# [226]	validation_0-logloss:0.133049
# [227]	validation_0-logloss:0.13304
# [228]	validation_0-logloss:0.133024
# [229]	validation_0-logloss:0.133006
# [230]	validation_0-logloss:0.13298
# [231]	validation_0-logloss:0.132949
# [232]	validation_0-logloss:0.132914
# [233]	validation_0-logloss:0.132864
# [234]	validation_0-logloss:0.132862
# [235]	validation_0-logloss:0.132858
# [236]	validation_0-logloss:0.132828
# [237]	validation_0-logloss:0.132815
# [238]	validation_0-logloss:0.13278
# [239]	validation_0-logloss:0.132767
# [240]	validation_0-logloss:0.132737
# [241]	validation_0-logloss:0.13272
# [242]	validation_0-logloss:0.132691
# [243]	validation_0-logloss:0.132675
# [244]	validation_0-logloss:0.13265
# [245]	validation_0-logloss:0.132607
# [246]	validation_0-logloss:0.132565
# [247]	validation_0-logloss:0.132554
# [248]	validation_0-logloss:0.132512
# [249]	validation_0-logloss:0.13249
# [250]	validation_0-logloss:0.132452
# [251]	validation_0-logloss:0.132426
# [252]	validation_0-logloss:0.132404
# [253]	validation_0-logloss:0.132396
# [254]	validation_0-logloss:0.132393
# [255]	validation_0-logloss:0.132373
# [256]	validation_0-logloss:0.132377
# [257]	validation_0-logloss:0.132365
# [258]	validation_0-logloss:0.13233
# [259]	validation_0-logloss:0.13231
# [260]	validation_0-logloss:0.132294
# [261]	validation_0-logloss:0.132281
# [262]	validation_0-logloss:0.132257
# [263]	validation_0-logloss:0.132221
# [264]	validation_0-logloss:0.132206
# [265]	validation_0-logloss:0.132193
# [266]	validation_0-logloss:0.132174
# [267]	validation_0-logloss:0.132169
# [268]	validation_0-logloss:0.132152
# [269]	validation_0-logloss:0.13214
# [270]	validation_0-logloss:0.13213
# [271]	validation_0-logloss:0.132126
# [272]	validation_0-logloss:0.132108
# [273]	validation_0-logloss:0.132097
# [274]	validation_0-logloss:0.132076
# [275]	validation_0-logloss:0.132076
# [276]	validation_0-logloss:0.132069
# [277]	validation_0-logloss:0.132059
# [278]	validation_0-logloss:0.132029
# [279]	validation_0-logloss:0.13202
# [280]	validation_0-logloss:0.132006
# [281]	validation_0-logloss:0.131987
# [282]	validation_0-logloss:0.131983
# [283]	validation_0-logloss:0.131979
# [284]	validation_0-logloss:0.131967
# [285]	validation_0-logloss:0.131965
# [286]	validation_0-logloss:0.131955
# [287]	validation_0-logloss:0.131948
# [288]	validation_0-logloss:0.131943
# [289]	validation_0-logloss:0.13192
# [290]	validation_0-logloss:0.131904
# [291]	validation_0-logloss:0.131895
# [292]	validation_0-logloss:0.131892
# [293]	validation_0-logloss:0.131887
# [294]	validation_0-logloss:0.131873
# [295]	validation_0-logloss:0.131853
# [296]	validation_0-logloss:0.131846
# [297]	validation_0-logloss:0.131839
# [298]	validation_0-logloss:0.131828
# [299]	validation_0-logloss:0.131815
# [300]	validation_0-logloss:0.131804
# [301]	validation_0-logloss:0.131796
# [302]	validation_0-logloss:0.131795
# [303]	validation_0-logloss:0.131782
# [304]	validation_0-logloss:0.131774
# [305]	validation_0-logloss:0.131768
# [306]	validation_0-logloss:0.131768
# [307]	validation_0-logloss:0.131748
# [308]	validation_0-logloss:0.131738
# [309]	validation_0-logloss:0.131731
# [310]	validation_0-logloss:0.131721
# [311]	validation_0-logloss:0.131715
# [312]	validation_0-logloss:0.131698
# [313]	validation_0-logloss:0.131694
# [314]	validation_0-logloss:0.131686
# [315]	validation_0-logloss:0.131675
# [316]	validation_0-logloss:0.131671
# [317]	validation_0-logloss:0.131668
# [318]	validation_0-logloss:0.131651
# [319]	validation_0-logloss:0.131647
# [320]	validation_0-logloss:0.131645
# [321]	validation_0-logloss:0.131633
# [322]	validation_0-logloss:0.131627
# [323]	validation_0-logloss:0.131616
# [324]	validation_0-logloss:0.131604
# [325]	validation_0-logloss:0.131598
# [326]	validation_0-logloss:0.1316
# [327]	validation_0-logloss:0.131582
# [328]	validation_0-logloss:0.131571
# [329]	validation_0-logloss:0.13157
# [330]	validation_0-logloss:0.131562
# [331]	validation_0-logloss:0.131558
# [332]	validation_0-logloss:0.131558
# [333]	validation_0-logloss:0.131554
# [334]	validation_0-logloss:0.131537
# [335]	validation_0-logloss:0.131538
# [336]	validation_0-logloss:0.131537
# [337]	validation_0-logloss:0.131532
# [338]	validation_0-logloss:0.131521
# [339]	validation_0-logloss:0.131523
# [340]	validation_0-logloss:0.131524
# [341]	validation_0-logloss:0.13152
# [342]	validation_0-logloss:0.131515
# [343]	validation_0-logloss:0.131511
# [344]	validation_0-logloss:0.131502
# [345]	validation_0-logloss:0.131489
# [346]	validation_0-logloss:0.131476
# [347]	validation_0-logloss:0.131466
# [348]	validation_0-logloss:0.131456
# [349]	validation_0-logloss:0.131451
# [350]	validation_0-logloss:0.131446
# [351]	validation_0-logloss:0.131443
# [352]	validation_0-logloss:0.131434
# [353]	validation_0-logloss:0.131434
# [354]	validation_0-logloss:0.131424
# [355]	validation_0-logloss:0.131426
# [356]	validation_0-logloss:0.131422
# [357]	validation_0-logloss:0.131413
# [358]	validation_0-logloss:0.131407
# [359]	validation_0-logloss:0.1314
# [360]	validation_0-logloss:0.131401
# [361]	validation_0-logloss:0.131395
# [362]	validation_0-logloss:0.131392
# [363]	validation_0-logloss:0.131387
# [364]	validation_0-logloss:0.13139
# [365]	validation_0-logloss:0.131384
# [366]	validation_0-logloss:0.131382
# [367]	validation_0-logloss:0.131375
# [368]	validation_0-logloss:0.131373
# [369]	validation_0-logloss:0.131365
# [370]	validation_0-logloss:0.13136
# [371]	validation_0-logloss:0.13136
# [372]	validation_0-logloss:0.131356
# [373]	validation_0-logloss:0.131352
# [374]	validation_0-logloss:0.131352
# [375]	validation_0-logloss:0.13135
# [376]	validation_0-logloss:0.131352
# [377]	validation_0-logloss:0.131346
# [378]	validation_0-logloss:0.13134
# [379]	validation_0-logloss:0.131338
# [380]	validation_0-logloss:0.131331
# [381]	validation_0-logloss:0.13133
# [382]	validation_0-logloss:0.13133
# [383]	validation_0-logloss:0.131324
# [384]	validation_0-logloss:0.131318
# [385]	validation_0-logloss:0.131317
# [386]	validation_0-logloss:0.13131
# [387]	validation_0-logloss:0.131306
# [388]	validation_0-logloss:0.131301
# [389]	validation_0-logloss:0.131302
# [390]	validation_0-logloss:0.131301
# [391]	validation_0-logloss:0.131302
# [392]	validation_0-logloss:0.131298
# [393]	validation_0-logloss:0.131293
# [394]	validation_0-logloss:0.131288
# [395]	validation_0-logloss:0.131285
# [396]	validation_0-logloss:0.131282
# [397]	validation_0-logloss:0.131278
# [398]	validation_0-logloss:0.131272
# [399]	validation_0-logloss:0.13127
# [400]	validation_0-logloss:0.131272
# [401]	validation_0-logloss:0.131271
# [402]	validation_0-logloss:0.131268
# [403]	validation_0-logloss:0.131269
# [404]	validation_0-logloss:0.131267
# [405]	validation_0-logloss:0.131262
# [406]	validation_0-logloss:0.13126
# [407]	validation_0-logloss:0.131259
# [408]	validation_0-logloss:0.131258
# [409]	validation_0-logloss:0.131252
# [410]	validation_0-logloss:0.131251
# [411]	validation_0-logloss:0.131251
# [412]	validation_0-logloss:0.131249
# [413]	validation_0-logloss:0.131247
# [414]	validation_0-logloss:0.131246
# [415]	validation_0-logloss:0.131245
# [416]	validation_0-logloss:0.131245
# [417]	validation_0-logloss:0.131242
# [418]	validation_0-logloss:0.131237
# [419]	validation_0-logloss:0.131236
# [420]	validation_0-logloss:0.131237
# [421]	validation_0-logloss:0.131235
# [422]	validation_0-logloss:0.131232
# [423]	validation_0-logloss:0.131231
# [424]	validation_0-logloss:0.131229
# [425]	validation_0-logloss:0.131229
# [426]	validation_0-logloss:0.131227
# [427]	validation_0-logloss:0.131226
# [428]	validation_0-logloss:0.131222
# [429]	validation_0-logloss:0.131219
# [430]	validation_0-logloss:0.13122
# [431]	validation_0-logloss:0.131218
# [432]	validation_0-logloss:0.131217
# [433]	validation_0-logloss:0.131211
# [434]	validation_0-logloss:0.131208
# [435]	validation_0-logloss:0.131207
# [436]	validation_0-logloss:0.131203
# [437]	validation_0-logloss:0.131203
# [438]	validation_0-logloss:0.1312
# [439]	validation_0-logloss:0.131198
# [440]	validation_0-logloss:0.131198
# [441]	validation_0-logloss:0.131195
# [442]	validation_0-logloss:0.131195
# [443]	validation_0-logloss:0.131195
# [444]	validation_0-logloss:0.131193
# [445]	validation_0-logloss:0.131193
# [446]	validation_0-logloss:0.131189
# [447]	validation_0-logloss:0.131187
# [448]	validation_0-logloss:0.131183
# [449]	validation_0-logloss:0.131184
# [450]	validation_0-logloss:0.131183
# [451]	validation_0-logloss:0.13118
# [452]	validation_0-logloss:0.131178
# [453]	validation_0-logloss:0.131177
# [454]	validation_0-logloss:0.131176
# [455]	validation_0-logloss:0.131174
# [456]	validation_0-logloss:0.131172
# [457]	validation_0-logloss:0.131169
# [458]	validation_0-logloss:0.131168
# [459]	validation_0-logloss:0.131168
# [460]	validation_0-logloss:0.131168
# [461]	validation_0-logloss:0.131165
# [462]	validation_0-logloss:0.131166
# [463]	validation_0-logloss:0.131167
# [464]	validation_0-logloss:0.131164
# [465]	validation_0-logloss:0.131163
# [466]	validation_0-logloss:0.131165
# [467]	validation_0-logloss:0.131164
# [468]	validation_0-logloss:0.131163
# [469]	validation_0-logloss:0.131164
# [470]	validation_0-logloss:0.131164
# [471]	validation_0-logloss:0.131163
# [472]	validation_0-logloss:0.131162
# [473]	validation_0-logloss:0.131162
# [474]	validation_0-logloss:0.131163
# [475]	validation_0-logloss:0.13116
# [476]	validation_0-logloss:0.131158
# [477]	validation_0-logloss:0.131156
# [478]	validation_0-logloss:0.131153
# [479]	validation_0-logloss:0.131151
# [480]	validation_0-logloss:0.131151
# [481]	validation_0-logloss:0.131149
# [482]	validation_0-logloss:0.131146
# [483]	validation_0-logloss:0.131144
# [484]	validation_0-logloss:0.131144
# [485]	validation_0-logloss:0.131142
# [486]	validation_0-logloss:0.131141
# [487]	validation_0-logloss:0.131142
# [488]	validation_0-logloss:0.131141
# [489]	validation_0-logloss:0.13114
# [490]	validation_0-logloss:0.131141
# [491]	validation_0-logloss:0.131139
# [492]	validation_0-logloss:0.131137
# [493]	validation_0-logloss:0.131137
# [494]	validation_0-logloss:0.131136
# [495]	validation_0-logloss:0.131135
# [496]	validation_0-logloss:0.131132
# [497]	validation_0-logloss:0.131132
# [498]	validation_0-logloss:0.13113
# [499]	validation_0-logloss:0.13113
# [500]	validation_0-logloss:0.13113
# [501]	validation_0-logloss:0.131129
# [502]	validation_0-logloss:0.131128
# [503]	validation_0-logloss:0.131126
# [504]	validation_0-logloss:0.131126
# [505]	validation_0-logloss:0.131126
# [506]	validation_0-logloss:0.131125
# [507]	validation_0-logloss:0.131124
# [508]	validation_0-logloss:0.131125
# [509]	validation_0-logloss:0.131124
# [510]	validation_0-logloss:0.131122
# [511]	validation_0-logloss:0.131121
# [512]	validation_0-logloss:0.131121
# [513]	validation_0-logloss:0.131119
# [514]	validation_0-logloss:0.131119
# [515]	validation_0-logloss:0.131119
# [516]	validation_0-logloss:0.131116
# [517]	validation_0-logloss:0.131116
# [518]	validation_0-logloss:0.131117
# [519]	validation_0-logloss:0.131115
# [520]	validation_0-logloss:0.131114
# [521]	validation_0-logloss:0.131113
# [522]	validation_0-logloss:0.131114
# [523]	validation_0-logloss:0.131113
# [524]	validation_0-logloss:0.131112
# [525]	validation_0-logloss:0.131112
# [526]	validation_0-logloss:0.131111
# [527]	validation_0-logloss:0.131109
# [528]	validation_0-logloss:0.131109
# [529]	validation_0-logloss:0.131108
# [530]	validation_0-logloss:0.131107
# [531]	validation_0-logloss:0.131106
# [532]	validation_0-logloss:0.131104
# [533]	validation_0-logloss:0.131103
# [534]	validation_0-logloss:0.131103
# [535]	validation_0-logloss:0.131102
# [536]	validation_0-logloss:0.131101
# [537]	validation_0-logloss:0.131101
# [538]	validation_0-logloss:0.131102
# [539]	validation_0-logloss:0.131101
# [540]	validation_0-logloss:0.131101
# [541]	validation_0-logloss:0.131101
# [542]	validation_0-logloss:0.131101
# [543]	validation_0-logloss:0.131099
# [544]	validation_0-logloss:0.1311
# [545]	validation_0-logloss:0.131099
# [546]	validation_0-logloss:0.131099
# [547]	validation_0-logloss:0.1311
# [548]	validation_0-logloss:0.131099
# [549]	validation_0-logloss:0.131098
# [550]	validation_0-logloss:0.131098
# [551]	validation_0-logloss:0.131098
# [552]	validation_0-logloss:0.131097
# [553]	validation_0-logloss:0.131097
# [554]	validation_0-logloss:0.131097
# [555]	validation_0-logloss:0.131096
# [556]	validation_0-logloss:0.131096
# [557]	validation_0-logloss:0.131096
# [558]	validation_0-logloss:0.131096
# [559]	validation_0-logloss:0.131096
# [560]	validation_0-logloss:0.131096
# [561]	validation_0-logloss:0.131098
# [562]	validation_0-logloss:0.131098
# [563]	validation_0-logloss:0.131098
# [564]	validation_0-logloss:0.131098
# [565]	validation_0-logloss:0.131098
# [566]	validation_0-logloss:0.131097
# [567]	validation_0-logloss:0.131097
# [568]	validation_0-logloss:0.131098
# [569]	validation_0-logloss:0.131097
# [570]	validation_0-logloss:0.131096
# [571]	validation_0-logloss:0.131096
# [572]	validation_0-logloss:0.131095
# [573]	validation_0-logloss:0.131096
# [574]	validation_0-logloss:0.131096
# [575]	validation_0-logloss:0.131095
# [576]	validation_0-logloss:0.131094
# [577]	validation_0-logloss:0.131094
# [578]	validation_0-logloss:0.131094
# [579]	validation_0-logloss:0.131094
# [580]	validation_0-logloss:0.131095
# [581]	validation_0-logloss:0.131095
# [582]	validation_0-logloss:0.131094
# [583]	validation_0-logloss:0.131094
# [584]	validation_0-logloss:0.131094
# [585]	validation_0-logloss:0.131094
# [586]	validation_0-logloss:0.131094
# [587]	validation_0-logloss:0.131093
# [588]	validation_0-logloss:0.131093
# [589]	validation_0-logloss:0.131092
# [590]	validation_0-logloss:0.131091
# [591]	validation_0-logloss:0.131092
# [592]	validation_0-logloss:0.131092
# [593]	validation_0-logloss:0.13109
# [594]	validation_0-logloss:0.131091
# [595]	validation_0-logloss:0.13109
# [596]	validation_0-logloss:0.13109
# [597]	validation_0-logloss:0.13109
# [598]	validation_0-logloss:0.13109
# [599]	validation_0-logloss:0.13109
# [600]	validation_0-logloss:0.13109
# [601]	validation_0-logloss:0.13109
# [602]	validation_0-logloss:0.13109
# [603]	validation_0-logloss:0.131089
# [604]	validation_0-logloss:0.131089
# [605]	validation_0-logloss:0.131089
# [606]	validation_0-logloss:0.131088
# [607]	validation_0-logloss:0.131089
# [608]	validation_0-logloss:0.131089
# [609]	validation_0-logloss:0.131089
# [610]	validation_0-logloss:0.131089
# [611]	validation_0-logloss:0.131089
# [612]	validation_0-logloss:0.131089
# [613]	validation_0-logloss:0.131089
# [614]	validation_0-logloss:0.131089
# [615]	validation_0-logloss:0.13109
# [616]	validation_0-logloss:0.13109
# [617]	validation_0-logloss:0.131089
# [618]	validation_0-logloss:0.13109
# [619]	validation_0-logloss:0.13109
# [620]	validation_0-logloss:0.131089
# [621]	validation_0-logloss:0.13109
# [622]	validation_0-logloss:0.131089
# [623]	validation_0-logloss:0.131089
# [624]	validation_0-logloss:0.131089
# [625]	validation_0-logloss:0.131089
# [626]	validation_0-logloss:0.131089
# [627]	validation_0-logloss:0.131089
# [628]	validation_0-logloss:0.131089
# [629]	validation_0-logloss:0.131089
# [630]	validation_0-logloss:0.13109
# [631]	validation_0-logloss:0.13109
# [632]	validation_0-logloss:0.13109
# [633]	validation_0-logloss:0.13109
# [634]	validation_0-logloss:0.13109
# [635]	validation_0-logloss:0.13109
# [636]	validation_0-logloss:0.13109
# [637]	validation_0-logloss:0.13109
# [638]	validation_0-logloss:0.13109
# [639]	validation_0-logloss:0.13109
# [640]	validation_0-logloss:0.13109
# [641]	validation_0-logloss:0.131089
# [642]	validation_0-logloss:0.13109
# [643]	validation_0-logloss:0.131089
# [644]	validation_0-logloss:0.131089
# [645]	validation_0-logloss:0.131089
# [646]	validation_0-logloss:0.131089
# [647]	validation_0-logloss:0.131089
# [648]	validation_0-logloss:0.131089
# [649]	validation_0-logloss:0.131089
# [650]	validation_0-logloss:0.131089
# [651]	validation_0-logloss:0.131089
# [652]	validation_0-logloss:0.131089
# [653]	validation_0-logloss:0.131089
# [654]	validation_0-logloss:0.131089
# [655]	validation_0-logloss:0.131089
# [656]	validation_0-logloss:0.131088
# Stopping. Best iteration:
# [606]	validation_0-logloss:0.131088
#
#                                      id  ret
# 0  001C8DA7-9969-4C51-A957-89F4C6E4999F    1
# 1  00468119-70E6-4C33-9F30-64BC91134253    1
# 2  005E0BA1-3B27-40F0-A231-5BAE6246599D    0
# 3  007EFD04-DBE6-4B14-A1AA-8A500C1D1EBC    1
# 4  008D289C-CE20-4F69-A756-0887895936E8    1
